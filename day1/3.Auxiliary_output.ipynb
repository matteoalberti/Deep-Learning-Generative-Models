# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
tf.__version__
# Out:
# '2.2.0'

# %% [markdown]
# # Get the data

# %%
# fashion_mnist
(x_train_full, y_train_full), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# rescale
x_train_full, x_test = x_train_full/255., x_test/255.
# Add channels last
x_train_full, x_test = np.expand_dims(x_train_full, axis=-1), np.expand_dims(x_test, axis=-1)
# Split train / validation
x_train, x_val,  y_train, y_val  = train_test_split(x_train_full, y_train_full, test_size=5000)
# Labels 
labels_map = np.array(['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                       'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'])

# %%
print('Train:', x_train.shape, x_train.dtype, y_train.shape, y_train.dtype)
print('Valid:', x_val.shape, x_val.dtype, y_val.shape, y_val.dtype)
print('Test :', x_test.shape, x_test.dtype, y_test.shape, y_test.dtype)
# Out:
# Train: (55000, 28, 28, 1) float64 (55000,) uint8
# Valid: (5000, 28, 28, 1) float64 (5000,) uint8
# Test : (10000, 28, 28, 1) float64 (10000,) uint8

# %% [markdown]
# # Define the model

# %% [markdown]
# In this exercise we define a model with an auxiliary output. To add an auxiliary output is a technique used in deep networks to reduce the vanishing of gradients, to stabilize the training and as regularisation (as it impose an constrains on the lower layers).
#
# In this small example it is unlikely that the extra loss will have a positive impact but for deeper network (e.g. GoogLeNet) it has been proven to be really effective.

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Flatten, Dense,\
                                    LeakyReLU, MaxPooling2D, Dropout
def build_model(x):
    x = Conv2D(16, 3, padding='same', activation="relu", use_bias=True)(x)
    x = Conv2D(32, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = MaxPooling2D(pool_size=(2,2))(x)

    aux_out = Conv2D(4, 1, padding='same', use_bias=True)(x)
    aux_out = Flatten()(aux_out)
    aux_out = Dropout(0.5)(aux_out)
    aux_out = Dense(10, activation='softmax', name="aux_output")(aux_out)

    x = Conv2D(64, 3, padding='same', use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.1)(x)
    x = MaxPooling2D(pool_size=(2,2))(x)

    main_out = Conv2D(16, 1, padding='same', use_bias=True)(x)
    main_out = Flatten()(main_out)
    main_out = Dropout(0.5)(main_out)
    main_out = Dense(10, activation='softmax', name="main_output")(main_out)
    return main_out, aux_out

# %%
input_ = Input(shape=x_train[0].shape)
main_out, aux_out = build_model(input_)
multi_out = tf.keras.Model(inputs=input_, outputs=[main_out, aux_out])
multi_out.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 28, 28, 16)   160         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 32)   4608        conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 28, 28, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 28, 28, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 14, 14, 32)   0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 14, 14, 64)   18432       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 14, 14, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 14, 14, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 64)     0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 7, 7, 16)     1040        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 14, 14, 4)    132         max_pooling2d[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 784)          0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 784)          0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 784)          0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 784)          0           flatten[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 10)           7850        dropout_1[0][0]
# __________________________________________________________________________________________________
# aux_output (Dense)              (None, 10)           7850        dropout[0][0]
# ==================================================================================================
# Total params: 40,456
# Trainable params: 40,264
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(multi_out)

# %% [markdown]
# When we compile, train or call the model we can feed the inputs and the targets following the same order used defining the model (this can lead to confusion!) or by passing a dictionary using their names as keys.

# %%
multi_out.compile(loss={"aux_output": 'sparse_categorical_crossentropy',
                        "main_output": 'sparse_categorical_crossentropy'},
                  loss_weights={"aux_output": 0.3, "main_output": 0.7},
                  optimizer="RMSProp",
                  metrics=["accuracy"])

# %%
history_multi = multi_out.fit(x=x_train, y=(y_train, y_train),
                              batch_size=16, epochs=10,
                              validation_data=(x_val, (y_val, y_val)))
# Out:
# Epoch 1/10
# 3438/3438 [==============================] - 16s 5ms/step - loss: 0.4786 - main_output_loss: 0.4679 - aux_output_loss: 0.5035 - main_output_accuracy: 0.8364 - aux_output_accuracy: 0.8229 - val_loss: 0.3189 - val_main_output_loss: 0.3138 - val_aux_output_loss: 0.3308 - val_main_output_accuracy: 0.8866 - val_aux_output_accuracy: 0.8820
# Epoch 2/10
# 3438/3438 [==============================] - 16s 5ms/step - loss: 0.3452 - main_output_loss: 0.3315 - aux_output_loss: 0.3771 - main_output_accuracy: 0.8834 - aux_output_accuracy: 0.8684 - val_loss: 0.2854 - val_main_output_loss: 0.2824 - val_aux_output_loss: 0.2926 - val_main_output_accuracy: 0.8964 - val_aux_output_accuracy: 0.8982
# Epoch 3/10
# 2317/3438 [===================>..........] - ETA: 4s - loss: 0.3152 - main_output_loss: 0.3021 - aux_output_loss: 0.3458 - main_output_accuracy: 0.8938 - aux_output_accuracy: 0.8782
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a965861c95cc> in <module>
# ----> 1 history_multi = multi_out.fit(x=x_train, y=(y_train, y_train),
#       2                               batch_size=16, epochs=10,
#       3                               validation_data=(x_val, (y_val, y_val)))
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# /usr/local/software/dl_course2020/envs/DL/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # Compare to single output

# %%
input_ = Input(shape=x_train[0].shape)
main_out, _ = build_model(input_)
single_out = tf.keras.Model(inputs=input_, outputs=main_out)
single_out.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 32)        4608
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 64)        18432
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 16)          1040
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 784)               0
# _________________________________________________________________
# main_output (Dense)          (None, 10)                7850
# =================================================================
# Total params: 32,474
# Trainable params: 32,282
# Non-trainable params: 192
# _________________________________________________________________

# %%
single_out.compile(loss='sparse_categorical_crossentropy',
                   optimizer="RMSProp",
                   metrics=["accuracy"])

# %%
history_single = single_out.fit(x=x_train, y=y_train,
                                batch_size=16, epochs=10,
                                validation_data=(x_val, y_val))
# Out:
# Epoch 1/10
# 3438/3438 [==============================] - 12s 3ms/step - loss: 0.4693 - accuracy: 0.8387 - val_loss: 0.2755 - val_accuracy: 0.9020
# Epoch 2/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.3324 - accuracy: 0.8851 - val_loss: 0.3117 - val_accuracy: 0.8830
# Epoch 3/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.3006 - accuracy: 0.8956 - val_loss: 0.2339 - val_accuracy: 0.9128
# Epoch 4/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.2849 - accuracy: 0.9007 - val_loss: 0.2324 - val_accuracy: 0.9170
# Epoch 5/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.2686 - accuracy: 0.9069 - val_loss: 0.2245 - val_accuracy: 0.9232
# Epoch 6/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.2552 - accuracy: 0.9106 - val_loss: 0.2079 - val_accuracy: 0.9300
# Epoch 7/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.2476 - accuracy: 0.9124 - val_loss: 0.2224 - val_accuracy: 0.9226
# Epoch 8/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.2392 - accuracy: 0.9161 - val_loss: 0.2113 - val_accuracy: 0.9258
# Epoch 9/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.2330 - accuracy: 0.9181 - val_loss: 0.2097 - val_accuracy: 0.9228
# Epoch 10/10
# 3438/3438 [==============================] - 11s 3ms/step - loss: 0.2264 - accuracy: 0.9205 - val_loss: 0.2011 - val_accuracy: 0.9280

# %%
plt.figure(figsize=(10,8))

plt.plot(history_single.history['val_loss'], label='val_loss')
plt.plot(history_single.history['val_accuracy'], label='val_acc')
plt.plot(history_multi.history['val_loss'], label='multi: val_loss')
plt.plot(history_multi.history['val_main_output_accuracy'], label='multi: val_main_acc')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %% [markdown]
# # Evaluate generalisation error
# The very last thing to do. After this no more tuning, accept the result as it is.

# %%
print("### Single Output ###")
tot_loss, main_acc = single_out.evaluate(x_test, y_test)

print("Test total loss    : %.3f"%tot_loss)
print("Test accuracy: %.3f"%main_acc)
print("Generalisation error: %.3f"%(1-main_acc))

print("### Multi Output ###")
tot_loss, main_loss, aux_loss, main_acc, aux_acc = multi_out.evaluate(x_test, y_test)

print("Test total loss    : %.3f"%tot_loss)
print("Test accuracy: %.3f"%main_acc)
print("Generalisation error: %.3f"%(1-main_acc))
# Out:
# ### Single Output ###
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2383 - accuracy: 0.9177
# Test total loss    : 0.238
# Test accuracy: 0.918
# Generalisation error: 0.082
# ### Multi Output ###
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2531 - main_output_loss: 0.2427 - aux_output_loss: 0.2772 - main_output_accuracy: 0.9157 - aux_output_accuracy: 0.9026
# Test total loss    : 0.253
# Test accuracy: 0.916
# Generalisation error: 0.084
